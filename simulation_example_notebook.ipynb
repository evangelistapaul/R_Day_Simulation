# %%
import os
os.chdir("/tmp")

# %%
# !rm -rf /tmp/R_Day_Simulation/

# %%
# %sh
# Clone the repository
git clone https://github.com/evangelistapaul/R_Day_Simulation

# %%
# %sh
# Install dependencies
pip install -r /tmp/R_Day_Simulation/requirements.txt

# %%
# !python3 /tmp/R_Day_Simulation/simulation.py

# %%
from IPython.display import Image, display
display(Image('/tmp/R_Day_Simulation/output/std_rand.png'))

# %%
# !python3 /tmp/R_Day_Simulation/build_images.py --mins 60

# %%
cmd = 'ls /tmp/R_Day_Simulation/output/*Rday.png | sort -n | tail -1'
cmd_result = os.popen(cmd).read().strip()
print(cmd_result)
display(Image(cmd_result))

# %%
# !python3 /tmp/R_Day_Simulation/stitch_images.py

# %%
# !cp /tmp/R_Day_Simulation/output/*mp4 /dbfs/mnt/container/R_Day/
